# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_name = '1_robot_moving_in_square'
df = pd.read_csv(f'data/{file_name}.csv')
df
# Out:
#       frame     time  computation_time  robot_id  radius        x        y  \
# 0         0   0.0000          0.000000         0    0.09 -4.00000 -4.00000
# 1         1   0.0050          0.000025         0    0.09 -3.99992 -4.00000
# 2         2   0.0100          0.000041         0    0.09 -3.99975 -4.00000
# 3         3   0.0150          0.000052         0    0.09 -3.99951 -4.00000
# 4         4   0.0200          0.000062         0    0.09 -3.99918 -4.00000
# ...     ...      ...               ...       ...     ...      ...      ...
# 2576   2576  12.8802          0.028437         0    0.09 -4.00091 -3.96920
# 2577   2577  12.8852          0.028449         0    0.09 -4.00083 -3.97171
# 2578   2578  12.8902          0.028461         0    0.09 -4.00076 -3.97413
# 2579   2579  12.8952          0.028473         0    0.09 -4.00069 -3.97647
# 2580   2580  12.9002          0.028485         0    0.09 -4.00063 -3.97873
#
#       velocity_x  velocity_y        speed  has_collided  pref_vel_x  \
# 0       0.000000    0.000000     0.000000            -1    0.000000
# 1    -799.984000 -800.000000  1131.360000            -1    3.500000
# 2       0.032806    0.000000     0.032806            -1    3.500000
# 3       0.049210    0.000000     0.049210            -1    3.500000
# 4       0.065613    0.000000     0.065613            -1    3.500000
# ...          ...         ...          ...           ...         ...
# 2576    0.015163   -0.517261     0.517483            -1    0.013753
# 2577    0.014686   -0.500858     0.501074            -1    0.013213
# 2578    0.014209   -0.484455     0.484664            -1    0.012667
# 2579    0.013733   -0.468053     0.468254            -1    0.012116
# 2580    0.013256   -0.451650     0.451844            -1    0.011558
#
#       pref_vel_y
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 2576   -0.467878
# 2577   -0.449389
# 2578   -0.430731
# 2579   -0.411880
# 2580   -0.392810
#
# [2581 rows x 13 columns]

# %%
num_robots = df['robot_id'].max() + 1
max_time = df['time'].max()

col_to_plot_name = 'speed'
y_max = df[col_to_plot_name].max()
y_min = df[col_to_plot_name].min()

# %%
fig = plt.figure()

if False and num_robots > 1:
    fig, axs = plt.subplots(num_robots, sharex=True, sharey=True)
    fig.suptitle('Robot speeds w/ 2021 kinematics')

    time = df[df['robot_id'] == 0]['time']
    max_speed = df['speed'].max()
    for robot_id, ax in enumerate(axs):
        ax.set_ylim([0, max_speed])
        robot = df[df['robot_id'] == robot_id]
        speed = robot['speed']
        ax.plot(time, speed)
else:
    fig.suptitle('Robot speeds w/ 2021 kinematics')
    ax = fig.add_subplot(111, autoscale_on=False, xlim=(0, max_time), 
                                                  ylim=(0, max_speed * 1.25))

    time = df[df['robot_id'] == 0]['time']
    max_speed = df['speed'].max()
    
    # ax.set_ylim([-5, 5])
    ax.set_ylim([y_min, y_max])
    robot = df[df['robot_id'] == 0]
    speed = robot['speed'] #['pref_vel_x'] #
    ax.grid()
    ax.plot(time, speed)

# %%
# Save plot
fig.savefig(f'plot/{file_name}.jpg', dpi=200)
